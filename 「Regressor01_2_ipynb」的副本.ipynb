# %% [markdown]
# <a href="https://colab.research.google.com/github/frankyehtw/hello-world/blob/master/%E3%80%8CRegressor01_2_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# create some data
X = np.linspace(-1, 1, 200)
np.random.shuffle(X)    # randomize the data
Y = 0.5 * X + 2 + np.random.normal(0, 0.05, (200, ))
# plot data
plt.scatter(X, Y)
plt.show()

X_train, Y_train = X[:160], Y[:160]     # train 前 160 data points
X_test, Y_test = X[160:], Y[160:]       # test 後 40 data points

# %%
#建立模型(1 neuron,  指定input的維度)
model = Sequential()
model.add(Dense(1, input_shape=(1,)))

# %%
# choose loss function and optimizing method
model.compile(loss='mse', optimizer='sgd')

#訓練模型
cost = model.fit(X_train, Y_train, epochs = 150)
# Out:
# Epoch 1/150
# 5/5 [==============================] - 1s 6ms/step - loss: 3.8296
# Epoch 2/150
# 5/5 [==============================] - 0s 5ms/step - loss: 3.1622
# Epoch 3/150
# 5/5 [==============================] - 0s 3ms/step - loss: 2.6150
# Epoch 4/150
# 5/5 [==============================] - 0s 3ms/step - loss: 2.1656
# Epoch 5/150
# 5/5 [==============================] - 0s 3ms/step - loss: 1.7969
# Epoch 6/150
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4938
# Epoch 7/150
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2449
# Epoch 8/150
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0402
# Epoch 9/150
# 5/5 [==============================] - 0s 7ms/step - loss: 0.8715
# Epoch 10/150
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7321
# Epoch 11/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6171
# Epoch 12/150
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5219
# ...

# %%
# test
print('\nTesting ------------')
cost = model.evaluate(X_test, Y_test)
print('test cost:', cost)
W, b = model.layers[0].get_weights()
print('Weights=', W, '\nbiases=', b)

# plotting the prediction
Y_pred = model.predict(X_test)
plt.scatter(X_test, Y_test)
plt.plot(X_test, Y_pred,'r')
plt.show()
# Out:
# Testing ------------
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0024
# test cost: 0.0023880540393292904
# Weights= [[0.5062006]]
# biases= [2.0052524]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
