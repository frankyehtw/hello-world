# %% [markdown]
# <a href="https://colab.research.google.com/github/frankyehtw/hello-world/blob/master/polyex3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
points = 200
X = np.linspace(-0.5, 0.5, points)
noise = np.random.normal(0, 0.02, X.shape)
y = np.square(X) + noise

# %%
model = Sequential()
model.add(Dense(10, input_dim =1, activation='relu'))
model.add(Dense(1))
model.compile(loss='mse', optimizer='Adam')
model.fit(X, y, batch_size= 10, epochs=200)
# Out:
# Epoch 1/200
# 20/20 [==============================] - 1s 1ms/step - loss: 0.0039
# Epoch 2/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 3/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 4/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 5/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 6/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 7/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 8/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 9/200
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0010
# Epoch 10/200
# 20/20 [==============================] - 0s 1ms/step - loss: 9.6575e-04
# Epoch 11/200
# 20/20 [==============================] - 0s 1ms/step - loss: 9.1526e-04
# Epoch 12/200
# ...

# %%
predictions = model.predict(X)
plt.scatter(X, y)
plt.plot(X, predictions, 'ro')
plt.show()
