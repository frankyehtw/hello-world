# %% [markdown]
# <a href="https://colab.research.google.com/github/frankyehtw/hello-world/blob/master/poly3_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np

# %%
x = list(np.arange(0,4,0.1))
y = list(map(lambda val: 4*val**3 + np.random.random()*20 , x) )
plt.scatter(x, y)

# %%
model = keras.Sequential()
model.add(layers.Dense(100, input_shape=(1,),activation ='sigmoid'))
model.add(layers.Dense(1))
model.compile(optimizer="sgd", loss="mse")
model.fit(x, y, epochs=2000)
# Out:
# Epoch 1/2000
# 2/2 [==============================] - 0s 7ms/step - loss: 8932.3320
# Epoch 2/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 3970.6147
# Epoch 3/2000
# 2/2 [==============================] - 0s 4ms/step - loss: 3756.2397
# Epoch 4/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 5927.0068
# Epoch 5/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 4075.8281
# Epoch 6/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 4749.1938
# Epoch 7/2000
# 2/2 [==============================] - 0s 3ms/step - loss: 4368.7119
# Epoch 8/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 2774.7058
# Epoch 9/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 2675.4893
# Epoch 10/2000
# 2/2 [==============================] - 0s 5ms/step - loss: 2801.5896
# Epoch 11/2000
# 2/2 [==============================] - 0s 6ms/step - loss: 2284.5691
# Epoch 12/2000
# ...

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x))
